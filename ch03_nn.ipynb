#   3.90000000e+00  4.00000000e+00  4.10000000e+00  4.20000000e+00
#   4.30000000e+00  4.40000000e+00  4.50000000e+00  4.60000000e+00
#   4.70000000e+00  4.80000000e+00  4.90000000e+00  5.00000000e+00
#   5.10000000e+00  5.20000000e+00  5.30000000e+00  5.40000000e+00
#   5.50000000e+00  5.60000000e+00  5.70000000e+00  5.80000000e+00
#   5.90000000e+00  6.00000000e+00  6.10000000e+00  6.20000000e+00
#   6.30000000e+00  6.40000000e+00  6.50000000e+00  6.60000000e+00
#   6.70000000e+00  6.80000000e+00  6.90000000e+00  7.00000000e+00
#   7.10000000e+00  7.20000000e+00  7.30000000e+00  7.40000000e+00
#   7.50000000e+00  7.60000000e+00  7.70000000e+00  7.80000000e+00
#   7.90000000e+00  8.00000000e+00  8.10000000e+00  8.20000000e+00
#   8.30000000e+00  8.40000000e+00  8.50000000e+00  8.60000000e+00
#   8.70000000e+00  8.80000000e+00  8.90000000e+00  9.00000000e+00
#   9.10000000e+00  9.20000000e+00  9.30000000e+00  9.40000000e+00
#   9.50000000e+00  9.60000000e+00  9.70000000e+00  9.80000000e+00
#   9.90000000e+00  1.00000000e+01]

# %%
plt.plot(x, sigmoid(x))

# %% [markdown]
# ## 3.2.2阶跃函数

# %%
def step_function(x):
    y = x > 0
    return y.astype(int)

# %%
x = np.array([-2.0, -1.0, 0, 1.0, 2.0])
x
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
y = step_function(x)
y
# Out:
# array([0, 0, 0, 1, 1])

# %%
x = np.arange(-5, 5, 0.1)
y = step_function(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 3.2.4 阶跃函数的实现

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
x = np.array([-1, 1, 2.0])
sigmoid(x)
# Out:
# array([0.26894142, 0.73105858, 0.88079708])

# %%
x = np.arange(-5.0, 5.0, 1)
y = sigmoid(x)
plt.plot(x, y)

# %% [markdown]
# ## 3.2.7 ReLU函数

# %%
def ReLU(x):
    return np.maximum(0, x)

# %%
x = np.arange(-5.0, 5, 0.01)
y = ReLU(x)
plt.plot(x,y)

# %% [markdown]
# # 3.3 多维数组的运算

# %% [markdown]
# ## 3.3.1 多维数组

# %%
A = np.array([1, 2, 3, 4])
A
# Out:
# array([1, 2, 3, 4])

# %%
np.ndim(A)
# Out:
# 1

# %%
np.shape(A)
# Out:
# (4,)

# %%
A.shape[0]
# Out:
# 4

# %%
B = np.array([[1,2], [3,4], [5,6]])
B
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
np.ndim(B)
# Out:
# 2

# %%
B.shape
# Out:
# (3, 2)

# %%
B.shape[1]
# Out:
# 2

# %% [markdown]
# ## 3.3.2 矩阵乘法

# %%
A = np.array([[1,2], [3,4]])
B = np.array([[5,6], [7,8]])
np.dot(A,B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %% [markdown]
# ## 3.3.3 神经网络的内积

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = np.array([1,2])
W = np.array([[1,3,5], [2,4,6]])

# %%
Y = np.dot(X, W)
Y
# Out:
# array([ 5, 11, 17])

# %% [markdown]
# # 3.4 3层神经网络的实现

# %% [markdown]
# ## 3.4.2 各层间信号传递的实现

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = np.array([1.0, 0.5])
W1 = np.array([[0.1,0.3,0.5], [0.2,0.4,0.6]])
B1 = np.array([0.1,0.2,0.3])
print(X)
print(W1)
print(B1)
# Out:
# [1.  0.5]
# [[0.1 0.3 0.5]
#  [0.2 0.4 0.6]]
# [0.1 0.2 0.3]

# %%
A1 = np.dot(X, W1) + B1
A1
# Out:
# array([0.3, 0.7, 1.1])

# %%
Z1 = sigmoid(A1)
Z1
# Out:
# array([0.57444252, 0.66818777, 0.75026011])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
W2 = np.array([[0.1,0.4], [0.2,0.5], [0.3,0.6]])
B2 = np.array([0.1,0.2])

# %%
W2
# Out:
# array([[0.1, 0.4],
#        [0.2, 0.5],
#        [0.3, 0.6]])

# %%
B2
# Out:
# array([0.1, 0.2])

# %%
A2 = np.dot(Z1, W2) + B2
Z2 = sigmoid(A2)

# %%
A2
# Out:
# array([0.51615984, 1.21402696])

# %%
Z2
# Out:
# array([0.62624937, 0.7710107 ])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def identity_function(x):
    return x

# %%
W3 = np.array([[0.1,0.3], [0.2,0.4]])
B3 = np.array([0.1,0.2])
A3 = np.dot(Z2, W3) + B3
Z3 = identity_function(A3)

# %%
A3
# Out:
# array([0.31682708, 0.69627909])

# %%
Z3
# Out:
# array([0.31682708, 0.69627909])

# %% [markdown]
# ## 3.4.3 代码实现小结

# %%
def init_network():
    network = {}
    network['W1'] = np.array([[0.1,0.3,0.5], [0.2,0.4,0.6]])
    network['b1'] = np.array([0.1,0.2,0.3])
    network['W2'] = np.array([[0.1,0.4], [0.2,0.5], [0.3,0.6]])
    network['b2'] = np.array([0.1,0.2])
    network['W3'] = np.array([[0.1,0.3], [0.2,0.4]])
    network['b3'] = np.array([0.1,0.2])

    return network

# %%
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    a1 = np.dot(x, W1) + b1
    z1 = sigmoid(a1)

    a2 = np.dot(z1, W2) + b2
    z2 = sigmoid(a2)

    a3 = np.dot(z2, W3) + b3
    y = identity_function(a3)

    return y

# %%
network = init_network()
x = np.array([1.0,0.5])
y = forward(network, x)

# %%
y
# Out:
# array([0.31682708, 0.69627909])

# %% [markdown]
# # 3.5 输出层设计

# %% [markdown]
# ## 3.5.1 恒等函数和softmax函数

# %%
def softmax_1(a):
    exp_a = np.exp(a)
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a

    return y

# %%
a = np.array([0.1,0.5,0.4])
y = softmax_1(a)
y
# Out:
# array([0.26030255, 0.38832577, 0.35137169])

# %% [markdown]
# ## 3.5.2 实现softmax函数时的注意事项

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def softmax(a):
    c = np.max(a)
    exp_a = np.exp(a - c)  # 溢出对策
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a

    return y

# %%
a = np.array([1010, 1000, 990])
y1 = softmax_1(a)
y = softmax(a)
print(f'没有做溢出处理：{y1}')
print(f'做了溢出处理：{y}')
# Out:
# C:\Users\chenj\AppData\Local\Temp\ipykernel_66404\1069441542.py:2: RuntimeWarning: overflow encountered in exp
#   exp_a = np.exp(a)
# C:\Users\chenj\AppData\Local\Temp\ipykernel_66404\1069441542.py:4: RuntimeWarning: invalid value encountered in divide
#   y = exp_a / sum_exp_a
# 没有做溢出处理：[nan nan nan]
# 做了溢出处理：[9.99954600e-01 4.53978686e-05 2.06106005e-09]

# %% [markdown]
# ## 3.5.3 softmax函数的特征

# %%
a = np.array([0.3, 2.9, 4.0])
y = softmax(a)
y
# Out:
# array([0.01821127, 0.24519181, 0.73659691])

# %% [markdown]
# # 3.6 手写数字识别
