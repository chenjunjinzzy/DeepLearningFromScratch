# %% [markdown]
# # 误差反向传播

# %%
# 导入matplotlib.pyplot模块，并命名为plt
import matplotlib.pyplot as plt
# 从mpl_toolkits.mplot3d模块中导入Axes3D类
from mpl_toolkits.mplot3d import Axes3D
# 导入numpy模块，并命名为np
import numpy as np

# 生成x轴数据列表，范围为-5到5，共100个点
x = np.linspace(-5, 5, 100)
# 生成y轴数据列表，范围为-5到5，共100个点
y = np.linspace(-5, 5, 100)
# 将x和y广播为两个矩阵，生成网格
x, y = np.meshgrid(x, y)
# 计算z轴数据列表，其中z = sin(sqrt(x^2 + y^2))
z = np.sin(np.sqrt(x**2 + y**2))

# 创建一个新的图形对象fig
fig = plt.figure()
# 向图形对象fig添加一个3D坐标轴对象ax，并设置为子图111中的第一个子图
ax = fig.add_subplot(111, projection='3d')

# 使用ax对象绘制3D曲面图，采用色图'viridis'
ax.plot_surface(x, y, z, cmap='viridis')

# 设置图表的标题
ax.set_title('3D')
# 设置x轴的标签
ax.set_xlabel('X')
# 设置y轴的标签
ax.set_ylabel('Y')
# 设置z轴的标签
ax.set_zlabel('Z')

# 显示图表
plt.show()
